# %% [markdown]
# ##Step to create a simple NN
# ---
#
# *   Imports required library
# *   Creating Neural Network model
# *   Set device
# *   Set hyperparameters
# *   Load data
# *   Initialize network
# *   Set loss and optimizer
# *   Train network
# *   Evaluation on test set

# %% [markdown]
# Step 1
#
#
# ---
# Imports required library

# %%
import os
import torch
import torch.nn as nn #has layer like linear, conv which ave parameters ans also contains loss function and activtion function which don't have parameters.
import torch.optim as optim #optimization algorithm like gradient decent, adam, stocstic gradient decent etc.
import torch.nn.functional as F #activation function that don't have parameter like relu, sigmoid etc.
from torch.utils.data import DataLoader #helps to create minibatch and prepare dataset easily
import torchvision.datasets as datasets #inbuilts dataset that already available
import torchvision.transforms as transforms #transform data

# %% [markdown]
# Step 2
#
#
# ---
# Create NN model

# %%
class NN(nn.Module):
  def __init__(self, num_features_size, num_classes):
    super(NN, self).__init__()
    self.fc1 = nn.Linear(in_features=num_features_size, out_features=30)
    self.fc2 = nn.Linear(in_features=30, out_features=num_classes)

  def forward(self, x):
    x = self.fc1(x)
    x = F.relu(x)
    x = self.fc2(x)
    return x

# %% [markdown]
# Step 3
#
#
# ---
# Initialize device

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# Step 4
#
#
# ---
# Set Hyperparameters

# %%
num_features_size = 28*28
num_classes = 10
learning_rate = .001
batch_size = 64
num_epoch = 100

# %% [markdown]
# Step 5
#
#
# ---
# Load data

# %%
# !pwd
os.chdir('/content/drive/MyDrive/Colab Notebooks/PyTorch Notebooks/Simple Neural Network')
# !pwd
train_dataset = datasets.MNIST(root='dataset/', train=True, transform=transforms.ToTensor(), download=True)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataset = datasets.MNIST(root='dataset/', train=False, transform=transforms.ToTensor(), download=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=True)

# %% [markdown]
# Step 6
#
#
#
# ---
#
# Initialize network

# %%
model = NN(num_features_size=num_features_size, num_classes=num_classes).to(device)

# %% [markdown]
# Step 7
#
#
#
# ---
#
# Set Loss and Optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), learning_rate)

# %% [markdown]
# Step 8
#
#
#
# ---
#
# Train network

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.reshape(X.shape[0],-1).to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.reshape(X.shape[0],-1).to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_loader, model, criterion, optimizer)
    test(test_loader, model, criterion)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.065746  [    0/60000]
# loss: 0.044115  [ 6400/60000]
# loss: 0.037196  [12800/60000]
# loss: 0.097457  [19200/60000]
# loss: 0.143526  [25600/60000]
# loss: 0.141766  [32000/60000]
# loss: 0.082688  [38400/60000]
# loss: 0.153142  [44800/60000]
# loss: 0.042780  [51200/60000]
# loss: 0.059465  [57600/60000]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.125319
#
# Epoch 2
# -------------------------------
# loss: 0.040234  [    0/60000]
# loss: 0.045320  [ 6400/60000]
# loss: 0.105207  [12800/60000]
# loss: 0.045443  [19200/60000]
# loss: 0.033144  [25600/60000]
# loss: 0.148147  [32000/60000]
# loss: 0.059500  [38400/60000]
# loss: 0.209931  [44800/60000]
# loss: 0.157610  [51200/60000]
# loss: 0.077134  [57600/60000]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.118978
#
# Epoch 3
# -------------------------------
# loss: 0.081573  [    0/60000]
# loss: 0.078365  [ 6400/60000]
# loss: 0.059417  [12800/60000]
# loss: 0.056702  [19200/60000]
# loss: 0.223327  [25600/60000]
# loss: 0.191421  [32000/60000]
# loss: 0.042640  [38400/60000]
# loss: 0.109298  [44800/60000]
# loss: 0.031550  [51200/60000]
# loss: 0.047297  [57600/60000]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.121142
#
# Epoch 4
# -------------------------------
# loss: 0.026296  [    0/60000]
# loss: 0.087257  [ 6400/60000]
# loss: 0.119928  [12800/60000]
# loss: 0.079160  [19200/60000]
# loss: 0.137032  [25600/60000]
# loss: 0.085870  [32000/60000]
# loss: 0.033621  [38400/60000]
# loss: 0.280529  [44800/60000]
# loss: 0.058657  [51200/60000]
# loss: 0.166354  [57600/60000]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.118068
#
# Epoch 5
# -------------------------------
# loss: 0.052855  [    0/60000]
# loss: 0.051015  [ 6400/60000]
# loss: 0.130186  [12800/60000]
# loss: 0.129065  [19200/60000]
# loss: 0.080799  [25600/60000]
# loss: 0.100528  [32000/60000]
# loss: 0.081595  [38400/60000]
# loss: 0.226394  [44800/60000]
# loss: 0.050481  [51200/60000]
# loss: 0.075261  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.119363
#
# Epoch 6
# -------------------------------
# loss: 0.029916  [    0/60000]
# loss: 0.046774  [ 6400/60000]
# loss: 0.277890  [12800/60000]
# loss: 0.086783  [19200/60000]
# loss: 0.124623  [25600/60000]
# loss: 0.054307  [32000/60000]
# loss: 0.046005  [38400/60000]
# loss: 0.026411  [44800/60000]
# loss: 0.016229  [51200/60000]
# loss: 0.057458  [57600/60000]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.114236
#
# Epoch 7
# -------------------------------
# loss: 0.073062  [    0/60000]
# loss: 0.046748  [ 6400/60000]
# loss: 0.035241  [12800/60000]
# loss: 0.056685  [19200/60000]
# loss: 0.044242  [25600/60000]
# loss: 0.048692  [32000/60000]
# loss: 0.032683  [38400/60000]
# loss: 0.064448  [44800/60000]
# loss: 0.072979  [51200/60000]
# loss: 0.052523  [57600/60000]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.118794
#
# Epoch 8
# -------------------------------
# loss: 0.125457  [    0/60000]
# loss: 0.028224  [ 6400/60000]
# loss: 0.185177  [12800/60000]
# loss: 0.055063  [19200/60000]
# loss: 0.023466  [25600/60000]
# loss: 0.095564  [32000/60000]
# loss: 0.024612  [38400/60000]
# loss: 0.072503  [44800/60000]
# loss: 0.120982  [51200/60000]
# loss: 0.050976  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.118292
#
# Epoch 9
# -------------------------------
# loss: 0.040069  [    0/60000]
# loss: 0.014128  [ 6400/60000]
# loss: 0.126001  [12800/60000]
# loss: 0.143318  [19200/60000]
# loss: 0.069528  [25600/60000]
# loss: 0.017636  [32000/60000]
# loss: 0.050060  [38400/60000]
# loss: 0.062990  [44800/60000]
# loss: 0.159445  [51200/60000]
# loss: 0.028098  [57600/60000]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.116050
#
# Epoch 10
# -------------------------------
# loss: 0.058279  [    0/60000]
# loss: 0.039790  [ 6400/60000]
# loss: 0.051270  [12800/60000]
# loss: 0.040667  [19200/60000]
# loss: 0.064490  [25600/60000]
# loss: 0.127523  [32000/60000]
# loss: 0.103895  [38400/60000]
# loss: 0.198642  [44800/60000]
# loss: 0.161028  [51200/60000]
# loss: 0.081567  [57600/60000]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.116523
#
# Epoch 11
# -------------------------------
# loss: 0.014862  [    0/60000]
# loss: 0.050431  [ 6400/60000]
# loss: 0.011911  [12800/60000]
# loss: 0.146396  [19200/60000]
# loss: 0.017838  [25600/60000]
# loss: 0.043296  [32000/60000]
# loss: 0.019605  [38400/60000]
# loss: 0.059033  [44800/60000]
# loss: 0.047424  [51200/60000]
# loss: 0.051221  [57600/60000]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.114829
#
# Epoch 12
# -------------------------------
# loss: 0.031211  [    0/60000]
# loss: 0.067912  [ 6400/60000]
# loss: 0.052985  [12800/60000]
# loss: 0.139171  [19200/60000]
# loss: 0.133011  [25600/60000]
# loss: 0.011287  [32000/60000]
# loss: 0.122365  [38400/60000]
# loss: 0.022886  [44800/60000]
# loss: 0.145936  [51200/60000]
# loss: 0.023014  [57600/60000]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.121261
#
# Epoch 13
# -------------------------------
# loss: 0.039068  [    0/60000]
# loss: 0.045154  [ 6400/60000]
# loss: 0.083820  [12800/60000]
# loss: 0.018552  [19200/60000]
# loss: 0.038509  [25600/60000]
# loss: 0.038683  [32000/60000]
# loss: 0.057520  [38400/60000]
# loss: 0.050727  [44800/60000]
# loss: 0.026469  [51200/60000]
# loss: 0.050603  [57600/60000]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.127749
#
# Epoch 14
# -------------------------------
# loss: 0.026768  [    0/60000]
# loss: 0.042308  [ 6400/60000]
# loss: 0.022990  [12800/60000]
# loss: 0.042246  [19200/60000]
# loss: 0.030086  [25600/60000]
# loss: 0.016288  [32000/60000]
# loss: 0.116211  [38400/60000]
# loss: 0.054567  [44800/60000]
# loss: 0.123682  [51200/60000]
# loss: 0.037818  [57600/60000]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.119019
#
# Epoch 15
# -------------------------------
# loss: 0.014735  [    0/60000]
# loss: 0.050698  [ 6400/60000]
# loss: 0.040784  [12800/60000]
# loss: 0.020898  [19200/60000]
# loss: 0.009541  [25600/60000]
# loss: 0.098032  [32000/60000]
# loss: 0.050075  [38400/60000]
# loss: 0.027199  [44800/60000]
# loss: 0.038273  [51200/60000]
# loss: 0.085465  [57600/60000]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.121180
#
# Epoch 16
# -------------------------------
# loss: 0.036990  [    0/60000]
# loss: 0.011761  [ 6400/60000]
# loss: 0.004381  [12800/60000]
# loss: 0.020116  [19200/60000]
# loss: 0.038238  [25600/60000]
# loss: 0.058793  [32000/60000]
# loss: 0.005448  [38400/60000]
# loss: 0.015822  [44800/60000]
# loss: 0.080708  [51200/60000]
# loss: 0.090538  [57600/60000]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.124450
#
# Epoch 17
# -------------------------------
# loss: 0.160245  [    0/60000]
# loss: 0.023693  [ 6400/60000]
# loss: 0.045104  [12800/60000]
# loss: 0.055601  [19200/60000]
# loss: 0.065337  [25600/60000]
# loss: 0.061139  [32000/60000]
# loss: 0.189471  [38400/60000]
# loss: 0.040763  [44800/60000]
# loss: 0.056637  [51200/60000]
# loss: 0.016755  [57600/60000]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.133194
#
# Epoch 18
# -------------------------------
# loss: 0.021602  [    0/60000]
# loss: 0.024848  [ 6400/60000]
# loss: 0.034668  [12800/60000]
# loss: 0.043998  [19200/60000]
# loss: 0.032552  [25600/60000]
# loss: 0.011004  [32000/60000]
# loss: 0.111491  [38400/60000]
# loss: 0.038627  [44800/60000]
# loss: 0.067514  [51200/60000]
# loss: 0.061724  [57600/60000]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.123195
#
# Epoch 19
# -------------------------------
# loss: 0.035773  [    0/60000]
# loss: 0.033663  [ 6400/60000]
# loss: 0.043861  [12800/60000]
# loss: 0.068905  [19200/60000]
# loss: 0.011512  [25600/60000]
# loss: 0.011644  [32000/60000]
# loss: 0.047432  [38400/60000]
# loss: 0.038469  [44800/60000]
# loss: 0.011072  [51200/60000]
# loss: 0.054547  [57600/60000]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.124023
#
# Epoch 20
# -------------------------------
# loss: 0.037093  [    0/60000]
# loss: 0.009789  [ 6400/60000]
# loss: 0.008588  [12800/60000]
# loss: 0.023188  [19200/60000]
# loss: 0.013235  [25600/60000]
# loss: 0.080812  [32000/60000]
# loss: 0.045777  [38400/60000]
# loss: 0.013611  [44800/60000]
# loss: 0.023085  [51200/60000]
# loss: 0.004482  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.131844
#
# Epoch 21
# -------------------------------
# loss: 0.031058  [    0/60000]
# loss: 0.054254  [ 6400/60000]
# loss: 0.004991  [12800/60000]
# loss: 0.025326  [19200/60000]
# loss: 0.019258  [25600/60000]
# loss: 0.085841  [32000/60000]
# loss: 0.060617  [38400/60000]
# loss: 0.045580  [44800/60000]
# loss: 0.043110  [51200/60000]
# loss: 0.006226  [57600/60000]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.128740
#
# Epoch 22
# -------------------------------
# loss: 0.025765  [    0/60000]
# loss: 0.010141  [ 6400/60000]
# loss: 0.014598  [12800/60000]
# loss: 0.014193  [19200/60000]
# loss: 0.037895  [25600/60000]
# loss: 0.013930  [32000/60000]
# loss: 0.125737  [38400/60000]
# loss: 0.023572  [44800/60000]
# loss: 0.131847  [51200/60000]
# loss: 0.010227  [57600/60000]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.128428
#
# Epoch 23
# -------------------------------
# loss: 0.038906  [    0/60000]
# loss: 0.094088  [ 6400/60000]
# loss: 0.022349  [12800/60000]
# loss: 0.076829  [19200/60000]
# loss: 0.034794  [25600/60000]
# loss: 0.014592  [32000/60000]
# loss: 0.124567  [38400/60000]
# loss: 0.110892  [44800/60000]
# loss: 0.063849  [51200/60000]
# loss: 0.021221  [57600/60000]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.124237
#
# Epoch 24
# -------------------------------
# loss: 0.058962  [    0/60000]
# loss: 0.029183  [ 6400/60000]
# loss: 0.025281  [12800/60000]
# loss: 0.013203  [19200/60000]
# loss: 0.148618  [25600/60000]
# loss: 0.046783  [32000/60000]
# loss: 0.008734  [38400/60000]
# loss: 0.009511  [44800/60000]
# loss: 0.050184  [51200/60000]
# loss: 0.005411  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.140782
#
# Epoch 25
# -------------------------------
# loss: 0.007703  [    0/60000]
# loss: 0.059388  [ 6400/60000]
# loss: 0.037019  [12800/60000]
# loss: 0.123431  [19200/60000]
# loss: 0.069141  [25600/60000]
# loss: 0.033584  [32000/60000]
# loss: 0.013350  [38400/60000]
# loss: 0.008458  [44800/60000]
# loss: 0.070040  [51200/60000]
# loss: 0.026475  [57600/60000]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.133555
#
# Epoch 26
# -------------------------------
# loss: 0.021977  [    0/60000]
# loss: 0.041302  [ 6400/60000]
# loss: 0.005441  [12800/60000]
# loss: 0.014998  [19200/60000]
# loss: 0.010048  [25600/60000]
# loss: 0.040886  [32000/60000]
# loss: 0.016076  [38400/60000]
# loss: 0.025037  [44800/60000]
# loss: 0.062224  [51200/60000]
# loss: 0.014649  [57600/60000]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.136782
#
# Epoch 27
# -------------------------------
# loss: 0.013183  [    0/60000]
# loss: 0.028013  [ 6400/60000]
# loss: 0.032285  [12800/60000]
# loss: 0.026099  [19200/60000]
# loss: 0.014938  [25600/60000]
# loss: 0.021837  [32000/60000]
# loss: 0.050344  [38400/60000]
# loss: 0.035677  [44800/60000]
# loss: 0.057332  [51200/60000]
# loss: 0.053675  [57600/60000]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.134922
#
# Epoch 28
# -------------------------------
# loss: 0.025914  [    0/60000]
# loss: 0.056847  [ 6400/60000]
# loss: 0.039593  [12800/60000]
# loss: 0.054839  [19200/60000]
# loss: 0.019973  [25600/60000]
# loss: 0.005473  [32000/60000]
# loss: 0.070876  [38400/60000]
# loss: 0.016873  [44800/60000]
# loss: 0.026525  [51200/60000]
# loss: 0.077976  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.145313
#
# Epoch 29
# -------------------------------
# loss: 0.017917  [    0/60000]
# loss: 0.033273  [ 6400/60000]
# loss: 0.068630  [12800/60000]
# loss: 0.006607  [19200/60000]
# loss: 0.017621  [25600/60000]
# loss: 0.057646  [32000/60000]
# loss: 0.047199  [38400/60000]
# loss: 0.076770  [44800/60000]
# loss: 0.053459  [51200/60000]
# loss: 0.061917  [57600/60000]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.138590
#
# Epoch 30
# -------------------------------
# loss: 0.012418  [    0/60000]
# loss: 0.029132  [ 6400/60000]
# loss: 0.019830  [12800/60000]
# loss: 0.016821  [19200/60000]
# loss: 0.016240  [25600/60000]
# loss: 0.022530  [32000/60000]
# loss: 0.052076  [38400/60000]
# loss: 0.022705  [44800/60000]
# loss: 0.040788  [51200/60000]
# loss: 0.051510  [57600/60000]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.144182
#
# Epoch 31
# -------------------------------
# loss: 0.030705  [    0/60000]
# loss: 0.015867  [ 6400/60000]
# loss: 0.009860  [12800/60000]
# loss: 0.037052  [19200/60000]
# loss: 0.038712  [25600/60000]
# loss: 0.029657  [32000/60000]
# loss: 0.052761  [38400/60000]
# loss: 0.024793  [44800/60000]
# loss: 0.006655  [51200/60000]
# loss: 0.079473  [57600/60000]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.140181
#
# Epoch 32
# -------------------------------
# loss: 0.024957  [    0/60000]
# loss: 0.010541  [ 6400/60000]
# loss: 0.010627  [12800/60000]
# loss: 0.027706  [19200/60000]
# loss: 0.028894  [25600/60000]
# loss: 0.007286  [32000/60000]
# loss: 0.062361  [38400/60000]
# loss: 0.001971  [44800/60000]
# loss: 0.002505  [51200/60000]
# loss: 0.033147  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.145587
#
# Epoch 33
# -------------------------------
# loss: 0.003309  [    0/60000]
# loss: 0.011125  [ 6400/60000]
# loss: 0.017537  [12800/60000]
# loss: 0.007471  [19200/60000]
# loss: 0.006812  [25600/60000]
# loss: 0.007259  [32000/60000]
# loss: 0.076266  [38400/60000]
# loss: 0.029468  [44800/60000]
# loss: 0.043593  [51200/60000]
# loss: 0.042781  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.153557
#
# Epoch 34
# -------------------------------
# loss: 0.007695  [    0/60000]
# loss: 0.014305  [ 6400/60000]
# loss: 0.016445  [12800/60000]
# loss: 0.030305  [19200/60000]
# loss: 0.013503  [25600/60000]
# loss: 0.010948  [32000/60000]
# loss: 0.023692  [38400/60000]
# loss: 0.020868  [44800/60000]
# loss: 0.015425  [51200/60000]
# loss: 0.100534  [57600/60000]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.149408
#
# Epoch 35
# -------------------------------
# loss: 0.023391  [    0/60000]
# loss: 0.021160  [ 6400/60000]
# loss: 0.008304  [12800/60000]
# loss: 0.052848  [19200/60000]
# loss: 0.009174  [25600/60000]
# loss: 0.010383  [32000/60000]
# loss: 0.016086  [38400/60000]
# loss: 0.038598  [44800/60000]
# loss: 0.015511  [51200/60000]
# loss: 0.048971  [57600/60000]
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.155478
#
# Epoch 36
# -------------------------------
# loss: 0.010282  [    0/60000]
# loss: 0.024082  [ 6400/60000]
# loss: 0.053813  [12800/60000]
# loss: 0.004239  [19200/60000]
# loss: 0.014588  [25600/60000]
# loss: 0.016638  [32000/60000]
# loss: 0.024724  [38400/60000]
# loss: 0.012287  [44800/60000]
# loss: 0.122181  [51200/60000]
# loss: 0.023079  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.147932
#
# Epoch 37
# -------------------------------
# loss: 0.009794  [    0/60000]
# loss: 0.021302  [ 6400/60000]
# loss: 0.002116  [12800/60000]
# loss: 0.006019  [19200/60000]
# loss: 0.034010  [25600/60000]
# loss: 0.022411  [32000/60000]
# loss: 0.014844  [38400/60000]
# loss: 0.009311  [44800/60000]
# loss: 0.017268  [51200/60000]
# loss: 0.007529  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.156728
#
# Epoch 38
# -------------------------------
# loss: 0.013513  [    0/60000]
# loss: 0.011103  [ 6400/60000]
# loss: 0.007704  [12800/60000]
# loss: 0.009355  [19200/60000]
# loss: 0.001826  [25600/60000]
# loss: 0.008282  [32000/60000]
# loss: 0.008309  [38400/60000]
# loss: 0.011066  [44800/60000]
# loss: 0.017808  [51200/60000]
# loss: 0.031509  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.160431
#
# Epoch 39
# -------------------------------
# loss: 0.020965  [    0/60000]
# loss: 0.021911  [ 6400/60000]
# loss: 0.004230  [12800/60000]
# loss: 0.000487  [19200/60000]
# loss: 0.019308  [25600/60000]
# loss: 0.016023  [32000/60000]
# loss: 0.028198  [38400/60000]
# loss: 0.024157  [44800/60000]
# loss: 0.003184  [51200/60000]
# loss: 0.011183  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.160877
#
# Epoch 40
# -------------------------------
# loss: 0.003913  [    0/60000]
# loss: 0.002972  [ 6400/60000]
# loss: 0.023475  [12800/60000]
# loss: 0.060125  [19200/60000]
# loss: 0.009463  [25600/60000]
# loss: 0.039160  [32000/60000]
# loss: 0.001873  [38400/60000]
# loss: 0.017778  [44800/60000]
# loss: 0.001829  [51200/60000]
# loss: 0.006520  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.162147
#
# Epoch 41
# -------------------------------
# loss: 0.027402  [    0/60000]
# loss: 0.006782  [ 6400/60000]
# loss: 0.001969  [12800/60000]
# loss: 0.025354  [19200/60000]
# loss: 0.017702  [25600/60000]
# loss: 0.018318  [32000/60000]
# loss: 0.006700  [38400/60000]
# loss: 0.012300  [44800/60000]
# loss: 0.011076  [51200/60000]
# loss: 0.017530  [57600/60000]
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.173465
#
# Epoch 42
# -------------------------------
# loss: 0.001776  [    0/60000]
# loss: 0.005175  [ 6400/60000]
# loss: 0.009519  [12800/60000]
# loss: 0.011268  [19200/60000]
# loss: 0.017838  [25600/60000]
# loss: 0.004570  [32000/60000]
# loss: 0.003879  [38400/60000]
# loss: 0.055825  [44800/60000]
# loss: 0.036983  [51200/60000]
# loss: 0.056692  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.166008
#
# Epoch 43
# -------------------------------
# loss: 0.010852  [    0/60000]
# loss: 0.005714  [ 6400/60000]
# loss: 0.041972  [12800/60000]
# loss: 0.014232  [19200/60000]
# loss: 0.029206  [25600/60000]
# loss: 0.016836  [32000/60000]
# loss: 0.015384  [38400/60000]
# loss: 0.006333  [44800/60000]
# loss: 0.026439  [51200/60000]
# loss: 0.025603  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.159323
#
# Epoch 44
# -------------------------------
# loss: 0.007767  [    0/60000]
# loss: 0.011781  [ 6400/60000]
# loss: 0.012463  [12800/60000]
# loss: 0.009213  [19200/60000]
# loss: 0.008538  [25600/60000]
# loss: 0.002641  [32000/60000]
# loss: 0.027457  [38400/60000]
# loss: 0.001219  [44800/60000]
# loss: 0.051376  [51200/60000]
# loss: 0.045067  [57600/60000]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.168767
#
# Epoch 45
# -------------------------------
# loss: 0.027108  [    0/60000]
# loss: 0.012987  [ 6400/60000]
# loss: 0.016458  [12800/60000]
# loss: 0.031140  [19200/60000]
# loss: 0.049491  [25600/60000]
# loss: 0.014042  [32000/60000]
# loss: 0.036597  [38400/60000]
# loss: 0.026318  [44800/60000]
# loss: 0.047420  [51200/60000]
# loss: 0.040264  [57600/60000]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.169184
#
# Epoch 46
# -------------------------------
# loss: 0.004737  [    0/60000]
# loss: 0.035671  [ 6400/60000]
# loss: 0.008223  [12800/60000]
# loss: 0.025262  [19200/60000]
# loss: 0.015282  [25600/60000]
# loss: 0.050343  [32000/60000]
# loss: 0.007761  [38400/60000]
# loss: 0.016511  [44800/60000]
# loss: 0.018666  [51200/60000]
# loss: 0.071873  [57600/60000]
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.168570
#
# Epoch 47
# -------------------------------
# loss: 0.015383  [    0/60000]
# loss: 0.004732  [ 6400/60000]
# loss: 0.009084  [12800/60000]
# loss: 0.005438  [19200/60000]
# loss: 0.000310  [25600/60000]
# loss: 0.026872  [32000/60000]
# loss: 0.015745  [38400/60000]
# loss: 0.015280  [44800/60000]
# loss: 0.002050  [51200/60000]
# loss: 0.017514  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.171102
#
# Epoch 48
# -------------------------------
# loss: 0.008238  [    0/60000]
# loss: 0.011674  [ 6400/60000]
# loss: 0.003007  [12800/60000]
# loss: 0.026536  [19200/60000]
# loss: 0.059123  [25600/60000]
# loss: 0.140190  [32000/60000]
# loss: 0.031395  [38400/60000]
# loss: 0.000795  [44800/60000]
# loss: 0.006273  [51200/60000]
# loss: 0.003792  [57600/60000]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.178255
#
# Epoch 49
# -------------------------------
# loss: 0.025225  [    0/60000]
# loss: 0.003641  [ 6400/60000]
# loss: 0.072743  [12800/60000]
# loss: 0.014826  [19200/60000]
# loss: 0.004957  [25600/60000]
# loss: 0.028615  [32000/60000]
# loss: 0.067367  [38400/60000]
# loss: 0.001188  [44800/60000]
# loss: 0.020198  [51200/60000]
# loss: 0.025259  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.177220
#
# Epoch 50
# -------------------------------
# loss: 0.003488  [    0/60000]
# loss: 0.008291  [ 6400/60000]
# loss: 0.006763  [12800/60000]
# loss: 0.049797  [19200/60000]
# loss: 0.010904  [25600/60000]
# loss: 0.029589  [32000/60000]
# loss: 0.015458  [38400/60000]
# loss: 0.071330  [44800/60000]
# loss: 0.000803  [51200/60000]
# loss: 0.003076  [57600/60000]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.179898
#
# Done!
